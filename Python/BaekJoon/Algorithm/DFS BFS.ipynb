# %%
def recursive_function(i):
    if i == 100:
        return
    print(i, '번째 함수에서', i+1, '번째 재귀 함수를 호출합니다')
    recursive_function(i+1)
    print(i,'재귀 함수 종료')

# %%
recursive_function(1)
# Out:
# 1 번째 함수에서 2 번째 재귀 함수를 호출합니다
# 2 번째 함수에서 3 번째 재귀 함수를 호출합니다
# 3 번째 함수에서 4 번째 재귀 함수를 호출합니다
# 4 번째 함수에서 5 번째 재귀 함수를 호출합니다
# 5 번째 함수에서 6 번째 재귀 함수를 호출합니다
# 6 번째 함수에서 7 번째 재귀 함수를 호출합니다
# 7 번째 함수에서 8 번째 재귀 함수를 호출합니다
# 8 번째 함수에서 9 번째 재귀 함수를 호출합니다
# 9 번째 함수에서 10 번째 재귀 함수를 호출합니다
# 10 번째 함수에서 11 번째 재귀 함수를 호출합니다
# 11 번째 함수에서 12 번째 재귀 함수를 호출합니다
# 12 번째 함수에서 13 번째 재귀 함수를 호출합니다
# 13 번째 함수에서 14 번째 재귀 함수를 호출합니다
# 14 번째 함수에서 15 번째 재귀 함수를 호출합니다
# 15 번째 함수에서 16 번째 재귀 함수를 호출합니다
# 16 번째 함수에서 17 번째 재귀 함수를 호출합니다
# 17 번째 함수에서 18 번째 재귀 함수를 호출합니다
# 18 번째 함수에서 19 번째 재귀 함수를 호출합니다
# 19 번째 함수에서 20 번째 재귀 함수를 호출합니다
# 20 번째 함수에서 21 번째 재귀 함수를 호출합니다
# 21 번째 함수에서 22 번째 재귀 함수를 호출합니다
# 22 번째 함수에서 23 번째 재귀 함수를 호출합니다
# 23 번째 함수에서 24 번째 재귀 함수를 호출합니다
# 24 번째 함수에서 25 번째 재귀 함수를 호출합니다
# 25 번째 함수에서 26 번째 재귀 함수를 호출합니다
# 26 번째 함수에서 27 번째 재귀 함수를 호출합니다
# 27 번째 함수에서 28 번째 재귀 함수를 호출합니다
# 28 번째 함수에서 29 번째 재귀 함수를 호출합니다
# 29 번째 함수에서 30 번째 재귀 함수를 호출합니다
# 30 번째 함수에서 31 번째 재귀 함수를 호출합니다
# 31 번째 함수에서 32 번째 재귀 함수를 호출합니다
# 32 번째 함수에서 33 번째 재귀 함수를 호출합니다
# 33 번째 함수에서 34 번째 재귀 함수를 호출합니다
# 34 번째 함수에서 35 번째 재귀 함수를 호출합니다
# 35 번째 함수에서 36 번째 재귀 함수를 호출합니다
# 36 번째 함수에서 37 번째 재귀 함수를 호출합니다
# 37 번째 함수에서 38 번째 재귀 함수를 호출합니다
# 38 번째 함수에서 39 번째 재귀 함수를 호출합니다
# 39 번째 함수에서 40 번째 재귀 함수를 호출합니다
# 40 번째 함수에서 41 번째 재귀 함수를 호출합니다
# 41 번째 함수에서 42 번째 재귀 함수를 호출합니다
# 42 번째 함수에서 43 번째 재귀 함수를 호출합니다
# 43 번째 함수에서 44 번째 재귀 함수를 호출합니다
# 44 번째 함수에서 45 번째 재귀 함수를 호출합니다
# 45 번째 함수에서 46 번째 재귀 함수를 호출합니다
# 46 번째 함수에서 47 번째 재귀 함수를 호출합니다
# 47 번째 함수에서 48 번째 재귀 함수를 호출합니다
# 48 번째 함수에서 49 번째 재귀 함수를 호출합니다
# 49 번째 함수에서 50 번째 재귀 함수를 호출합니다
# 50 번째 함수에서 51 번째 재귀 함수를 호출합니다
# 51 번째 함수에서 52 번째 재귀 함수를 호출합니다
# 52 번째 함수에서 53 번째 재귀 함수를 호출합니다
# 53 번째 함수에서 54 번째 재귀 함수를 호출합니다
# 54 번째 함수에서 55 번째 재귀 함수를 호출합니다
# 55 번째 함수에서 56 번째 재귀 함수를 호출합니다
# 56 번째 함수에서 57 번째 재귀 함수를 호출합니다
# 57 번째 함수에서 58 번째 재귀 함수를 호출합니다
# 58 번째 함수에서 59 번째 재귀 함수를 호출합니다
# 59 번째 함수에서 60 번째 재귀 함수를 호출합니다
# 60 번째 함수에서 61 번째 재귀 함수를 호출합니다
# 61 번째 함수에서 62 번째 재귀 함수를 호출합니다
# 62 번째 함수에서 63 번째 재귀 함수를 호출합니다
# 63 번째 함수에서 64 번째 재귀 함수를 호출합니다
# 64 번째 함수에서 65 번째 재귀 함수를 호출합니다
# 65 번째 함수에서 66 번째 재귀 함수를 호출합니다
# 66 번째 함수에서 67 번째 재귀 함수를 호출합니다
# 67 번째 함수에서 68 번째 재귀 함수를 호출합니다
# 68 번째 함수에서 69 번째 재귀 함수를 호출합니다
# 69 번째 함수에서 70 번째 재귀 함수를 호출합니다
# 70 번째 함수에서 71 번째 재귀 함수를 호출합니다
# 71 번째 함수에서 72 번째 재귀 함수를 호출합니다
# 72 번째 함수에서 73 번째 재귀 함수를 호출합니다
# 73 번째 함수에서 74 번째 재귀 함수를 호출합니다
# 74 번째 함수에서 75 번째 재귀 함수를 호출합니다
# 75 번째 함수에서 76 번째 재귀 함수를 호출합니다
# 76 번째 함수에서 77 번째 재귀 함수를 호출합니다
# 77 번째 함수에서 78 번째 재귀 함수를 호출합니다
# 78 번째 함수에서 79 번째 재귀 함수를 호출합니다
# 79 번째 함수에서 80 번째 재귀 함수를 호출합니다
# 80 번째 함수에서 81 번째 재귀 함수를 호출합니다
# 81 번째 함수에서 82 번째 재귀 함수를 호출합니다
# 82 번째 함수에서 83 번째 재귀 함수를 호출합니다
# 83 번째 함수에서 84 번째 재귀 함수를 호출합니다
# 84 번째 함수에서 85 번째 재귀 함수를 호출합니다
# 85 번째 함수에서 86 번째 재귀 함수를 호출합니다
# 86 번째 함수에서 87 번째 재귀 함수를 호출합니다
# 87 번째 함수에서 88 번째 재귀 함수를 호출합니다
# 88 번째 함수에서 89 번째 재귀 함수를 호출합니다
# 89 번째 함수에서 90 번째 재귀 함수를 호출합니다
# 90 번째 함수에서 91 번째 재귀 함수를 호출합니다
# 91 번째 함수에서 92 번째 재귀 함수를 호출합니다
# 92 번째 함수에서 93 번째 재귀 함수를 호출합니다
# 93 번째 함수에서 94 번째 재귀 함수를 호출합니다
# 94 번째 함수에서 95 번째 재귀 함수를 호출합니다
# 95 번째 함수에서 96 번째 재귀 함수를 호출합니다
# 96 번째 함수에서 97 번째 재귀 함수를 호출합니다
# 97 번째 함수에서 98 번째 재귀 함수를 호출합니다
# 98 번째 함수에서 99 번째 재귀 함수를 호출합니다
# 99 번째 함수에서 100 번째 재귀 함수를 호출합니다
# 99 재귀 함수 종료
# 98 재귀 함수 종료
# 97 재귀 함수 종료
# 96 재귀 함수 종료
# 95 재귀 함수 종료
# 94 재귀 함수 종료
# 93 재귀 함수 종료
# 92 재귀 함수 종료
# 91 재귀 함수 종료
# 90 재귀 함수 종료
# 89 재귀 함수 종료
# 88 재귀 함수 종료
# 87 재귀 함수 종료
# 86 재귀 함수 종료
# 85 재귀 함수 종료
# 84 재귀 함수 종료
# 83 재귀 함수 종료
# 82 재귀 함수 종료
# 81 재귀 함수 종료
# 80 재귀 함수 종료
# 79 재귀 함수 종료
# 78 재귀 함수 종료
# 77 재귀 함수 종료
# 76 재귀 함수 종료
# 75 재귀 함수 종료
# 74 재귀 함수 종료
# 73 재귀 함수 종료
# 72 재귀 함수 종료
# 71 재귀 함수 종료
# 70 재귀 함수 종료
# 69 재귀 함수 종료
# 68 재귀 함수 종료
# 67 재귀 함수 종료
# 66 재귀 함수 종료
# 65 재귀 함수 종료
# 64 재귀 함수 종료
# 63 재귀 함수 종료
# 62 재귀 함수 종료
# 61 재귀 함수 종료
# 60 재귀 함수 종료
# 59 재귀 함수 종료
# 58 재귀 함수 종료
# 57 재귀 함수 종료
# 56 재귀 함수 종료
# 55 재귀 함수 종료
# 54 재귀 함수 종료
# 53 재귀 함수 종료
# 52 재귀 함수 종료
# 51 재귀 함수 종료
# 50 재귀 함수 종료
# 49 재귀 함수 종료
# 48 재귀 함수 종료
# 47 재귀 함수 종료
# 46 재귀 함수 종료
# 45 재귀 함수 종료
# 44 재귀 함수 종료
# 43 재귀 함수 종료
# 42 재귀 함수 종료
# 41 재귀 함수 종료
# 40 재귀 함수 종료
# 39 재귀 함수 종료
# 38 재귀 함수 종료
# 37 재귀 함수 종료
# 36 재귀 함수 종료
# 35 재귀 함수 종료
# 34 재귀 함수 종료
# 33 재귀 함수 종료
# 32 재귀 함수 종료
# 31 재귀 함수 종료
# 30 재귀 함수 종료
# 29 재귀 함수 종료
# 28 재귀 함수 종료
# 27 재귀 함수 종료
# 26 재귀 함수 종료
# 25 재귀 함수 종료
# 24 재귀 함수 종료
# 23 재귀 함수 종료
# 22 재귀 함수 종료
# 21 재귀 함수 종료
# 20 재귀 함수 종료
# 19 재귀 함수 종료
# 18 재귀 함수 종료
# 17 재귀 함수 종료
# 16 재귀 함수 종료
# 15 재귀 함수 종료
# 14 재귀 함수 종료
# 13 재귀 함수 종료
# 12 재귀 함수 종료
# 11 재귀 함수 종료
# 10 재귀 함수 종료
# 9 재귀 함수 종료
# 8 재귀 함수 종료
# 7 재귀 함수 종료
# 6 재귀 함수 종료
# 5 재귀 함수 종료
# 4 재귀 함수 종료
# 3 재귀 함수 종료
# 2 재귀 함수 종료
# 1 재귀 함수 종료
